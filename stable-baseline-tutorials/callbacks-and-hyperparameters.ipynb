# %% [markdown]
# ## Hyperparameter tuning with Callbacks

# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO, A2C, SAC
from stable_baselines3.common.evaluation import evaluate_policy

# %%
eval_env = gym.make('Pendulum-v1')
default_model = SAC(
    'MlpPolicy',
    eval_env,
    verbose=0,
    seed=0,
    batch_size=64,
    policy_kwargs=dict(net_arch=[64,64]),
).learn(8_000)

# %%
mean_reward, std_reward = evaluate_policy(default_model, eval_env, n_eval_episodes=100)
print(f'Default Mean reward: {mean_reward} +/- {std_reward}')
# Out:
# Default Mean reward: -609.9966125883581 +/- 77.17879235387625

# %%
tuned_model = SAC(
    'MlpPolicy',
    eval_env,
    verbose=0,
    seed=0,
    batch_size=128,
    learning_rate=3e-4,
    policy_kwargs=dict(net_arch=[256,256]),
).learn(8_000)
mean_reward, std_reward = evaluate_policy(tuned_model, eval_env, n_eval_episodes=100)
print(f'Tuned Mean reward: {mean_reward} +/- {std_reward}')
# Out:
# Tuned Mean reward: -162.31068963069788 +/- 99.2422378410119

# %% [markdown]
# ## Callbacks
#
# To build a custom callback, create a class derived from `BaseCallback` and override the methods for the events you want to handle (_on_training_start, _on_step and other useful variables like self.model for the RL model)

# %% [markdown]
# The access to variables like `self.model` allows you to change hyperparameters on the fly, for example we can implement a learning rate scheduler that decreases the learning rate linearly over time.

# %%
from stable_baselines3.common.callbacks import BaseCallback

class CustomCallback(BaseCallback):
    """
    :param verbose: (int) Verbosity level 0: not output 1: info 2: debug
    """
    def __init__(self, verbose=0):
        super(CustomCallback, self).__init__(verbose)
    def _on_training_start(self) -> None: pass # Method called before rollout starts
    def _on_rollout_start(self) -> None: pass # A rollout is collection of environment interaction using the current policy
    def _on_step(self) -> bool: return True # This method will be called by the model after each call to `env.step()`. It returns a boolean indicating whether training should continue.
    def _on_rollout_end(self) -> None: pass # This event is triggered before updating the policy
    def _on_training_end(self) -> None: pass # Method called at the end of training

# %% [markdown]
# > A simple callback implementation

# %%
class SimpleCallback(BaseCallback):
    """
    A simple callback that can only be called twice before stopping training
    :param verbose: (int) Verbosity level 0: not output 1: info 2: debug
    """
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self._called = False
    def _on_step(self) -> bool:
        if not self._called:
            print(f'callback - first call')
            self._called = True
            return True # Returning True will continue training
        print(f'callback - second call')
        return False # Returning False will stop training

# %%
model = SAC('MlpPolicy', 'Pendulum-v1', verbose=1).learn(10_000, callback=SimpleCallback())
# Out:
# Using cpu device
# Creating environment from the given name 'Pendulum-v1'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# callback - first call
# callback - second call

# %% [markdown]
# ## First Example: Auto Saving best model

# %%
import os

import numpy as np

from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.results_plotter import load_results, ts2xy

class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq, log_dir, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            if len(x) > 0:
                # Mean training reward over the last 100 episodes
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print("Num timesteps: {}".format(self.num_timesteps))
                    print(
                        "Best mean reward: {:.2f} - Last mean reward per episode: {:.2f}".format(
                            self.best_mean_reward, mean_reward
                        )
                    )

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    # Example for saving best model
                    if self.verbose > 0:
                        print("Saving new best model at {} timesteps".format(x[-1]))
                        print("Saving new best model to {}.zip".format(self.save_path))
                    self.model.save(self.save_path)

        return True

# %%
# Create log dir
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = make_vec_env("CartPole-v1", n_envs=1, monitor_dir=log_dir)
# it is equivalent to:
# env = gym.make('CartPole-v1')
# env = Monitor(env, log_dir)
# env = DummyVecEnv([lambda: env])

# Create Callback
callback = SaveOnBestTrainingRewardCallback(check_freq=20, log_dir=log_dir, verbose=1)

model = A2C("MlpPolicy", env, verbose=0)
model.learn(total_timesteps=5000, callback=callback)
# Out:
# Num timesteps: 20
# Best mean reward: -inf - Last mean reward per episode: 10.00
# Saving new best model at 10 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 40
# Best mean reward: 10.00 - Last mean reward per episode: 11.00
# Saving new best model at 22 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 60
# Best mean reward: 11.00 - Last mean reward per episode: 11.00
# Num timesteps: 80
# Best mean reward: 11.00 - Last mean reward per episode: 23.33
# Saving new best model at 70 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 100
# Best mean reward: 23.33 - Last mean reward per episode: 23.33
# Num timesteps: 120
# Best mean reward: 23.33 - Last mean reward per episode: 23.33
# Num timesteps: 140
# Best mean reward: 23.33 - Last mean reward per episode: 30.75
# Saving new best model at 123 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 160
# Best mean reward: 30.75 - Last mean reward per episode: 29.00
# Num timesteps: 180
# Best mean reward: 30.75 - Last mean reward per episode: 29.67
# Num timesteps: 200
# Best mean reward: 30.75 - Last mean reward per episode: 29.67
# Num timesteps: 220
# Best mean reward: 30.75 - Last mean reward per episode: 29.14
# Num timesteps: 240
# Best mean reward: 30.75 - Last mean reward per episode: 29.14
# Num timesteps: 260
# Best mean reward: 30.75 - Last mean reward per episode: 30.38
# Num timesteps: 280
# Best mean reward: 30.75 - Last mean reward per episode: 30.67
# Num timesteps: 300
# Best mean reward: 30.75 - Last mean reward per episode: 29.90
# Num timesteps: 320
# Best mean reward: 30.75 - Last mean reward per episode: 29.90
# Num timesteps: 340
# Best mean reward: 30.75 - Last mean reward per episode: 28.08
# Num timesteps: 360
# Best mean reward: 30.75 - Last mean reward per episode: 28.08
# Num timesteps: 380
# Best mean reward: 30.75 - Last mean reward per episode: 26.79
# Num timesteps: 400
# Best mean reward: 30.75 - Last mean reward per episode: 26.60
# Num timesteps: 420
# Best mean reward: 30.75 - Last mean reward per episode: 26.00
# Num timesteps: 440
# Best mean reward: 30.75 - Last mean reward per episode: 26.00
# Num timesteps: 460
# Best mean reward: 30.75 - Last mean reward per episode: 26.59
# Num timesteps: 480
# Best mean reward: 30.75 - Last mean reward per episode: 26.11
# Num timesteps: 500
# Best mean reward: 30.75 - Last mean reward per episode: 25.84
# Num timesteps: 520
# Best mean reward: 30.75 - Last mean reward per episode: 24.67
# Num timesteps: 540
# Best mean reward: 30.75 - Last mean reward per episode: 24.67
# Num timesteps: 560
# Best mean reward: 30.75 - Last mean reward per episode: 25.09
# Num timesteps: 580
# Best mean reward: 30.75 - Last mean reward per episode: 25.09
# Num timesteps: 600
# Best mean reward: 30.75 - Last mean reward per episode: 25.70
# Num timesteps: 620
# Best mean reward: 30.75 - Last mean reward per episode: 25.70
# Num timesteps: 640
# Best mean reward: 30.75 - Last mean reward per episode: 26.00
# Num timesteps: 660
# Best mean reward: 30.75 - Last mean reward per episode: 26.04
# Num timesteps: 680
# Best mean reward: 30.75 - Last mean reward per episode: 25.50
# Num timesteps: 700
# Best mean reward: 30.75 - Last mean reward per episode: 24.82
# Num timesteps: 720
# Best mean reward: 30.75 - Last mean reward per episode: 24.82
# Num timesteps: 740
# Best mean reward: 30.75 - Last mean reward per episode: 24.57
# Num timesteps: 760
# Best mean reward: 30.75 - Last mean reward per episode: 24.35
# Num timesteps: 780
# Best mean reward: 30.75 - Last mean reward per episode: 23.97
# Num timesteps: 800
# Best mean reward: 30.75 - Last mean reward per episode: 23.79
# Num timesteps: 820
# Best mean reward: 30.75 - Last mean reward per episode: 23.88
# Num timesteps: 840
# Best mean reward: 30.75 - Last mean reward per episode: 23.88
# Num timesteps: 860
# Best mean reward: 30.75 - Last mean reward per episode: 24.09
# Num timesteps: 880
# Best mean reward: 30.75 - Last mean reward per episode: 24.06
# Num timesteps: 900
# Best mean reward: 30.75 - Last mean reward per episode: 24.14
# Num timesteps: 920
# Best mean reward: 30.75 - Last mean reward per episode: 24.14
# Num timesteps: 940
# Best mean reward: 30.75 - Last mean reward per episode: 24.14
# Num timesteps: 960
# Best mean reward: 30.75 - Last mean reward per episode: 24.84
# Num timesteps: 980
# Best mean reward: 30.75 - Last mean reward per episode: 24.90
# Num timesteps: 1000
# Best mean reward: 30.75 - Last mean reward per episode: 24.95
# Num timesteps: 1020
# Best mean reward: 30.75 - Last mean reward per episode: 24.83
# Num timesteps: 1040
# Best mean reward: 30.75 - Last mean reward per episode: 24.83
# Num timesteps: 1060
# Best mean reward: 30.75 - Last mean reward per episode: 24.83
# Num timesteps: 1080
# Best mean reward: 30.75 - Last mean reward per episode: 25.52
# Num timesteps: 1100
# Best mean reward: 30.75 - Last mean reward per episode: 25.47
# Num timesteps: 1120
# Best mean reward: 30.75 - Last mean reward per episode: 25.47
# Num timesteps: 1140
# Best mean reward: 30.75 - Last mean reward per episode: 25.24
# Num timesteps: 1160
# Best mean reward: 30.75 - Last mean reward per episode: 25.24
# Num timesteps: 1180
# Best mean reward: 30.75 - Last mean reward per episode: 25.24
# Num timesteps: 1200
# Best mean reward: 30.75 - Last mean reward per episode: 25.24
# Num timesteps: 1220
# Best mean reward: 30.75 - Last mean reward per episode: 26.35
# Num timesteps: 1240
# Best mean reward: 30.75 - Last mean reward per episode: 26.17
# Num timesteps: 1260
# Best mean reward: 30.75 - Last mean reward per episode: 26.06
# Num timesteps: 1280
# Best mean reward: 30.75 - Last mean reward per episode: 26.06
# Num timesteps: 1300
# Best mean reward: 30.75 - Last mean reward per episode: 26.06
# Num timesteps: 1320
# Best mean reward: 30.75 - Last mean reward per episode: 26.06
# Num timesteps: 1340
# Best mean reward: 30.75 - Last mean reward per episode: 26.06
# Num timesteps: 1360
# Best mean reward: 30.75 - Last mean reward per episode: 26.67
# Num timesteps: 1380
# Best mean reward: 30.75 - Last mean reward per episode: 26.67
# Num timesteps: 1400
# Best mean reward: 30.75 - Last mean reward per episode: 26.67
# Num timesteps: 1420
# Best mean reward: 30.75 - Last mean reward per episode: 26.67
# Num timesteps: 1440
# Best mean reward: 30.75 - Last mean reward per episode: 27.46
# Num timesteps: 1460
# Best mean reward: 30.75 - Last mean reward per episode: 27.34
# Num timesteps: 1480
# Best mean reward: 30.75 - Last mean reward per episode: 27.37
# Num timesteps: 1500
# Best mean reward: 30.75 - Last mean reward per episode: 27.22
# Num timesteps: 1520
# Best mean reward: 30.75 - Last mean reward per episode: 27.22
# Num timesteps: 1540
# Best mean reward: 30.75 - Last mean reward per episode: 27.22
# Num timesteps: 1560
# Best mean reward: 30.75 - Last mean reward per episode: 27.71
# Num timesteps: 1580
# Best mean reward: 30.75 - Last mean reward per episode: 27.58
# Num timesteps: 1600
# Best mean reward: 30.75 - Last mean reward per episode: 27.48
# Num timesteps: 1620
# Best mean reward: 30.75 - Last mean reward per episode: 27.22
# Num timesteps: 1640
# Best mean reward: 30.75 - Last mean reward per episode: 27.32
# Num timesteps: 1660
# Best mean reward: 30.75 - Last mean reward per episode: 27.32
# Num timesteps: 1680
# Best mean reward: 30.75 - Last mean reward per episode: 27.02
# Num timesteps: 1700
# Best mean reward: 30.75 - Last mean reward per episode: 27.02
# Num timesteps: 1720
# Best mean reward: 30.75 - Last mean reward per episode: 27.17
# Num timesteps: 1740
# Best mean reward: 30.75 - Last mean reward per episode: 27.17
# Num timesteps: 1760
# Best mean reward: 30.75 - Last mean reward per episode: 27.17
# Num timesteps: 1780
# Best mean reward: 30.75 - Last mean reward per episode: 27.53
# Num timesteps: 1800
# Best mean reward: 30.75 - Last mean reward per episode: 27.54
# Num timesteps: 1820
# Best mean reward: 30.75 - Last mean reward per episode: 27.41
# Num timesteps: 1840
# Best mean reward: 30.75 - Last mean reward per episode: 27.34
# Num timesteps: 1860
# Best mean reward: 30.75 - Last mean reward per episode: 27.28
# Num timesteps: 1880
# Best mean reward: 30.75 - Last mean reward per episode: 27.28
# Num timesteps: 1900
# Best mean reward: 30.75 - Last mean reward per episode: 27.33
# Num timesteps: 1920
# Best mean reward: 30.75 - Last mean reward per episode: 27.20
# Num timesteps: 1940
# Best mean reward: 30.75 - Last mean reward per episode: 27.14
# Num timesteps: 1960
# Best mean reward: 30.75 - Last mean reward per episode: 27.14
# Num timesteps: 1980
# Best mean reward: 30.75 - Last mean reward per episode: 27.33
# Num timesteps: 2000
# Best mean reward: 30.75 - Last mean reward per episode: 27.33
# Num timesteps: 2020
# Best mean reward: 30.75 - Last mean reward per episode: 27.42
# Num timesteps: 2040
# Best mean reward: 30.75 - Last mean reward per episode: 27.35
# Num timesteps: 2060
# Best mean reward: 30.75 - Last mean reward per episode: 27.41
# Num timesteps: 2080
# Best mean reward: 30.75 - Last mean reward per episode: 27.41
# Num timesteps: 2100
# Best mean reward: 30.75 - Last mean reward per episode: 27.41
# Num timesteps: 2120
# Best mean reward: 30.75 - Last mean reward per episode: 27.75
# Num timesteps: 2140
# Best mean reward: 30.75 - Last mean reward per episode: 27.75
# Num timesteps: 2160
# Best mean reward: 30.75 - Last mean reward per episode: 27.69
# Num timesteps: 2180
# Best mean reward: 30.75 - Last mean reward per episode: 27.69
# Num timesteps: 2200
# Best mean reward: 30.75 - Last mean reward per episode: 27.73
# Num timesteps: 2220
# Best mean reward: 30.75 - Last mean reward per episode: 27.69
# Num timesteps: 2240
# Best mean reward: 30.75 - Last mean reward per episode: 27.63
# Num timesteps: 2260
# Best mean reward: 30.75 - Last mean reward per episode: 27.63
# Num timesteps: 2280
# Best mean reward: 30.75 - Last mean reward per episode: 27.63
# Num timesteps: 2300
# Best mean reward: 30.75 - Last mean reward per episode: 27.63
# Num timesteps: 2320
# Best mean reward: 30.75 - Last mean reward per episode: 28.12
# Num timesteps: 2340
# Best mean reward: 30.75 - Last mean reward per episode: 28.06
# Num timesteps: 2360
# Best mean reward: 30.75 - Last mean reward per episode: 28.06
# Num timesteps: 2380
# Best mean reward: 30.75 - Last mean reward per episode: 28.06
# Num timesteps: 2400
# Best mean reward: 30.75 - Last mean reward per episode: 28.06
# Num timesteps: 2420
# Best mean reward: 30.75 - Last mean reward per episode: 28.76
# Num timesteps: 2440
# Best mean reward: 30.75 - Last mean reward per episode: 28.76
# Num timesteps: 2460
# Best mean reward: 30.75 - Last mean reward per episode: 28.75
# Num timesteps: 2480
# Best mean reward: 30.75 - Last mean reward per episode: 28.75
# Num timesteps: 2500
# Best mean reward: 30.75 - Last mean reward per episode: 28.86
# Num timesteps: 2520
# Best mean reward: 30.75 - Last mean reward per episode: 28.95
# Num timesteps: 2540
# Best mean reward: 30.75 - Last mean reward per episode: 28.95
# Num timesteps: 2560
# Best mean reward: 30.75 - Last mean reward per episode: 28.95
# Num timesteps: 2580
# Best mean reward: 30.75 - Last mean reward per episode: 28.95
# Num timesteps: 2600
# Best mean reward: 30.75 - Last mean reward per episode: 29.38
# Num timesteps: 2620
# Best mean reward: 30.75 - Last mean reward per episode: 29.38
# Num timesteps: 2640
# Best mean reward: 30.75 - Last mean reward per episode: 29.38
# Num timesteps: 2660
# Best mean reward: 30.75 - Last mean reward per episode: 29.72
# Num timesteps: 2680
# Best mean reward: 30.75 - Last mean reward per episode: 29.72
# Num timesteps: 2700
# Best mean reward: 30.75 - Last mean reward per episode: 29.72
# Num timesteps: 2720
# Best mean reward: 30.75 - Last mean reward per episode: 30.08
# Num timesteps: 2740
# Best mean reward: 30.75 - Last mean reward per episode: 30.02
# Num timesteps: 2760
# Best mean reward: 30.75 - Last mean reward per episode: 30.00
# Num timesteps: 2780
# Best mean reward: 30.75 - Last mean reward per episode: 29.86
# Num timesteps: 2800
# Best mean reward: 30.75 - Last mean reward per episode: 29.86
# Num timesteps: 2820
# Best mean reward: 30.75 - Last mean reward per episode: 29.86
# Num timesteps: 2840
# Best mean reward: 30.75 - Last mean reward per episode: 29.86
# Num timesteps: 2860
# Best mean reward: 30.75 - Last mean reward per episode: 29.86
# Num timesteps: 2880
# Best mean reward: 30.75 - Last mean reward per episode: 30.56
# Num timesteps: 2900
# Best mean reward: 30.75 - Last mean reward per episode: 30.56
# Num timesteps: 2920
# Best mean reward: 30.75 - Last mean reward per episode: 30.56
# Num timesteps: 2940
# Best mean reward: 30.75 - Last mean reward per episode: 30.80
# Saving new best model at 2926 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2960
# Best mean reward: 30.80 - Last mean reward per episode: 30.80
# Num timesteps: 2980
# Best mean reward: 30.80 - Last mean reward per episode: 30.80
# Num timesteps: 3000
# Best mean reward: 30.80 - Last mean reward per episode: 30.80
# Num timesteps: 3020
# Best mean reward: 30.80 - Last mean reward per episode: 30.80
# Num timesteps: 3040
# Best mean reward: 30.80 - Last mean reward per episode: 31.67
# Saving new best model at 3040 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3060
# Best mean reward: 31.67 - Last mean reward per episode: 31.67
# Num timesteps: 3080
# Best mean reward: 31.67 - Last mean reward per episode: 31.67
# Num timesteps: 3100
# Best mean reward: 31.67 - Last mean reward per episode: 31.82
# Saving new best model at 3087 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3120
# Best mean reward: 31.82 - Last mean reward per episode: 31.82
# Num timesteps: 3140
# Best mean reward: 31.82 - Last mean reward per episode: 31.82
# Num timesteps: 3160
# Best mean reward: 31.82 - Last mean reward per episode: 32.07
# Saving new best model at 3143 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3180
# Best mean reward: 32.07 - Last mean reward per episode: 32.07
# Num timesteps: 3200
# Best mean reward: 32.07 - Last mean reward per episode: 32.25
# Saving new best model at 3193 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3220
# Best mean reward: 32.25 - Last mean reward per episode: 32.25
# Num timesteps: 3240
# Best mean reward: 32.25 - Last mean reward per episode: 32.25
# Num timesteps: 3260
# Best mean reward: 32.25 - Last mean reward per episode: 32.59
# Saving new best model at 3259 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3280
# Best mean reward: 32.59 - Last mean reward per episode: 32.59
# Num timesteps: 3300
# Best mean reward: 32.59 - Last mean reward per episode: 32.59
# Num timesteps: 3320
# Best mean reward: 32.59 - Last mean reward per episode: 33.02
# Saving new best model at 3312 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3340
# Best mean reward: 33.02 - Last mean reward per episode: 33.02
# Num timesteps: 3360
# Best mean reward: 33.02 - Last mean reward per episode: 33.29
# Saving new best model at 3351 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3380
# Best mean reward: 33.29 - Last mean reward per episode: 33.29
# Num timesteps: 3400
# Best mean reward: 33.29 - Last mean reward per episode: 33.23
# Num timesteps: 3420
# Best mean reward: 33.29 - Last mean reward per episode: 32.97
# Num timesteps: 3440
# Best mean reward: 33.29 - Last mean reward per episode: 32.97
# Num timesteps: 3460
# Best mean reward: 33.29 - Last mean reward per episode: 32.97
# Num timesteps: 3480
# Best mean reward: 33.29 - Last mean reward per episode: 33.21
# Num timesteps: 3500
# Best mean reward: 33.29 - Last mean reward per episode: 33.21
# Num timesteps: 3520
# Best mean reward: 33.29 - Last mean reward per episode: 33.21
# Num timesteps: 3540
# Best mean reward: 33.29 - Last mean reward per episode: 33.46
# Saving new best model at 3524 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3560
# Best mean reward: 33.46 - Last mean reward per episode: 33.46
# Num timesteps: 3580
# Best mean reward: 33.46 - Last mean reward per episode: 33.46
# Num timesteps: 3600
# Best mean reward: 33.46 - Last mean reward per episode: 33.86
# Saving new best model at 3590 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3620
# Best mean reward: 33.86 - Last mean reward per episode: 33.86
# Num timesteps: 3640
# Best mean reward: 33.86 - Last mean reward per episode: 33.86
# Num timesteps: 3660
# Best mean reward: 33.86 - Last mean reward per episode: 34.09
# Saving new best model at 3652 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3680
# Best mean reward: 34.09 - Last mean reward per episode: 34.09
# Num timesteps: 3700
# Best mean reward: 34.09 - Last mean reward per episode: 34.09
# Num timesteps: 3720
# Best mean reward: 34.09 - Last mean reward per episode: 34.09
# Num timesteps: 3740
# Best mean reward: 34.09 - Last mean reward per episode: 34.09
# Num timesteps: 3760
# Best mean reward: 34.09 - Last mean reward per episode: 34.09
# Num timesteps: 3780
# Best mean reward: 34.09 - Last mean reward per episode: 34.09
# Num timesteps: 3800
# Best mean reward: 34.09 - Last mean reward per episode: 35.05
# Saving new best model at 3781 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3820
# Best mean reward: 35.05 - Last mean reward per episode: 35.05
# Num timesteps: 3840
# Best mean reward: 35.05 - Last mean reward per episode: 35.05
# Num timesteps: 3860
# Best mean reward: 35.05 - Last mean reward per episode: 35.47
# Saving new best model at 3846 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3880
# Best mean reward: 35.47 - Last mean reward per episode: 35.47
# Num timesteps: 3900
# Best mean reward: 35.47 - Last mean reward per episode: 35.47
# Num timesteps: 3920
# Best mean reward: 35.47 - Last mean reward per episode: 35.47
# Num timesteps: 3940
# Best mean reward: 35.47 - Last mean reward per episode: 35.47
# Num timesteps: 3960
# Best mean reward: 35.47 - Last mean reward per episode: 36.33
# Saving new best model at 3955 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3980
# Best mean reward: 36.33 - Last mean reward per episode: 36.35
# Saving new best model at 3972 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4000
# Best mean reward: 36.35 - Last mean reward per episode: 36.35
# Num timesteps: 4020
# Best mean reward: 36.35 - Last mean reward per episode: 36.35
# Num timesteps: 4040
# Best mean reward: 36.35 - Last mean reward per episode: 36.35
# Num timesteps: 4060
# Best mean reward: 36.35 - Last mean reward per episode: 36.35
# Num timesteps: 4080
# Best mean reward: 36.35 - Last mean reward per episode: 36.35
# Num timesteps: 4100
# Best mean reward: 36.35 - Last mean reward per episode: 37.36
# Saving new best model at 4098 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4120
# Best mean reward: 37.36 - Last mean reward per episode: 37.36
# Num timesteps: 4140
# Best mean reward: 37.36 - Last mean reward per episode: 37.36
# Num timesteps: 4160
# Best mean reward: 37.36 - Last mean reward per episode: 37.36
# Num timesteps: 4180
# Best mean reward: 37.36 - Last mean reward per episode: 37.36
# Num timesteps: 4200
# Best mean reward: 37.36 - Last mean reward per episode: 38.19
# Saving new best model at 4194 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4220
# Best mean reward: 38.19 - Last mean reward per episode: 38.19
# Num timesteps: 4240
# Best mean reward: 38.19 - Last mean reward per episode: 38.19
# Num timesteps: 4260
# Best mean reward: 38.19 - Last mean reward per episode: 38.19
# Num timesteps: 4280
# Best mean reward: 38.19 - Last mean reward per episode: 38.19
# Num timesteps: 4300
# Best mean reward: 38.19 - Last mean reward per episode: 38.19
# Num timesteps: 4320
# Best mean reward: 38.19 - Last mean reward per episode: 39.19
# Saving new best model at 4318 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4340
# Best mean reward: 39.19 - Last mean reward per episode: 39.19
# Num timesteps: 4360
# Best mean reward: 39.19 - Last mean reward per episode: 39.19
# Num timesteps: 4380
# Best mean reward: 39.19 - Last mean reward per episode: 39.19
# Num timesteps: 4400
# Best mean reward: 39.19 - Last mean reward per episode: 39.19
# Num timesteps: 4420
# Best mean reward: 39.19 - Last mean reward per episode: 39.97
# Saving new best model at 4413 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4440
# Best mean reward: 39.97 - Last mean reward per episode: 39.97
# Num timesteps: 4460
# Best mean reward: 39.97 - Last mean reward per episode: 39.97
# Num timesteps: 4480
# Best mean reward: 39.97 - Last mean reward per episode: 39.97
# Num timesteps: 4500
# Best mean reward: 39.97 - Last mean reward per episode: 39.97
# Num timesteps: 4520
# Best mean reward: 39.97 - Last mean reward per episode: 40.51
# Saving new best model at 4503 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4540
# Best mean reward: 40.51 - Last mean reward per episode: 40.58
# Saving new best model at 4528 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4560
# Best mean reward: 40.58 - Last mean reward per episode: 40.58
# Num timesteps: 4580
# Best mean reward: 40.58 - Last mean reward per episode: 40.58
# Num timesteps: 4600
# Best mean reward: 40.58 - Last mean reward per episode: 40.58
# Num timesteps: 4620
# Best mean reward: 40.58 - Last mean reward per episode: 41.14
# Saving new best model at 4605 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4640
# Best mean reward: 41.14 - Last mean reward per episode: 41.14
# Num timesteps: 4660
# Best mean reward: 41.14 - Last mean reward per episode: 41.14
# Num timesteps: 4680
# Best mean reward: 41.14 - Last mean reward per episode: 41.14
# Num timesteps: 4700
# Best mean reward: 41.14 - Last mean reward per episode: 41.89
# Saving new best model at 4691 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4720
# Best mean reward: 41.89 - Last mean reward per episode: 41.89
# Num timesteps: 4740
# Best mean reward: 41.89 - Last mean reward per episode: 41.89
# Num timesteps: 4760
# Best mean reward: 41.89 - Last mean reward per episode: 41.89
# Num timesteps: 4780
# Best mean reward: 41.89 - Last mean reward per episode: 41.89
# Num timesteps: 4800
# Best mean reward: 41.89 - Last mean reward per episode: 41.89
# Num timesteps: 4820
# Best mean reward: 41.89 - Last mean reward per episode: 42.99
# Saving new best model at 4817 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4840
# Best mean reward: 42.99 - Last mean reward per episode: 42.99
# Num timesteps: 4860
# Best mean reward: 42.99 - Last mean reward per episode: 43.01
# Saving new best model at 4853 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4880
# Best mean reward: 43.01 - Last mean reward per episode: 43.01
# Num timesteps: 4900
# Best mean reward: 43.01 - Last mean reward per episode: 43.01
# Num timesteps: 4920
# Best mean reward: 43.01 - Last mean reward per episode: 43.19
# Saving new best model at 4910 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4940
# Best mean reward: 43.19 - Last mean reward per episode: 43.19
# Num timesteps: 4960
# Best mean reward: 43.19 - Last mean reward per episode: 43.19
# Num timesteps: 4980
# Best mean reward: 43.19 - Last mean reward per episode: 43.19
# Num timesteps: 5000
# Best mean reward: 43.19 - Last mean reward per episode: 43.19

# %% [markdown]
# ## Second Example: Plotting the training reward in real-time

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook


class PlottingCallback(BaseCallback):
    """
    Callback for plotting the performance in realtime.

    :param verbose: (int)
    """
    def __init__(self, verbose=1):
        super().__init__(verbose)
        self._plot = None

    def _on_step(self) -> bool:
        # get the monitor's data
        x, y = ts2xy(load_results(log_dir), 'timesteps')
        if self._plot is None: # make the plot
            plt.ion()
            fig = plt.figure(figsize=(6,3))
            ax = fig.add_subplot(111)
            line, = ax.plot(x, y)
            self._plot = (line, ax, fig)
            plt.show()
        else: # update and rescale the plot
            self._plot[0].set_data(x, y)
            self._plot[-2].relim()
            self._plot[-2].set_xlim([self.locals["total_timesteps"] * -0.02,
                                    self.locals["total_timesteps"] * 1.02])
            self._plot[-2].autoscale_view(True,True,True)
            self._plot[-1].canvas.draw()

# Create log dir
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = make_vec_env('MountainCarContinuous-v0', n_envs=1, monitor_dir=log_dir)

plotting_callback = PlottingCallback()

model = PPO('MlpPolicy', env, verbose=0)
model.learn(10000, callback=plotting_callback)
# Out:
# <div id='15e9d3ef-4c3b-498a-ac42-a386e83fc082'></div>
